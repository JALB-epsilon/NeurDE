# %%
import torch

# %%
import h5py

file_path = "/home/junyi/NeurDE/Cylinder/data_base/cylinder_case.h5"
with h5py.File(file_path, 'r') as f:
    print(f["T"][()].shape)
    data = f["T"][()]
# Out:
# (1000, 300, 500)

# %%
import matplotlib.pyplot as plt
plt.imshow(data[100, :, :])
